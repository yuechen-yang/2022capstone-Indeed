# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/Colab\ Notebooks/capstone/Yuechen-Indeed-capstone-data
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Colab Notebooks/capstone/Yuechen-Indeed-capstone-data

# %% [markdown]
# ## Load data

# %%
data=pd.read_csv("add10-1.csv")

# %%
data
# Out:
#               company_name                                     position  \
# 0        American Airlines                           Software Developer
# 1        American Airlines              Customer Service Representative
# 2        American Airlines                           Reservations Agent
# 3        American Airlines              Customer Service Representative
# 4        American Airlines              Customer Service Representative
# ...                    ...                                          ...
# 2328195     LyondellBasell              Customer Service Representative
# 2328196     LyondellBasell        Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell  Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell        Quality Control Laboratory Technician
# 2328199     LyondellBasell                               Lab Technician
#
#                  location  rate  \
# 0          Fort Worth, TX   4.0
# 1        Philadelphia, PA   3.0
# ...

# %%
finace_data=pd.read_csv("company_refinitiv_detail_data_with_assets.csv")
finace_data_use=finace_data[["gvkey","Price To Book Value Per Share (Daily Time Series Ratio)","Return on Invested Capital - %","Return on Average Total Assets - %, TTM"]]
finace_data_use
# Out:
#       gvkey  Price To Book Value Per Share (Daily Time Series Ratio)  \
# 0      1045                                          -1.563627
# 1      1075                                           1.313080
# 2      1078                                           7.229932
# 3      1161                                          24.440415
# 4      1177                                                NaN
# ..      ...                                                ...
# 718  199356                                           4.742451
# 719  260774                                                NaN
# 720  260778                                                NaN
# 721  294524                                                NaN
# 722  316056                                                NaN
#
#      Return on Invested Capital - %  Return on Average Total Assets - %, TTM
# 0                               NaN                                -4.937124
# ...

# %%
ana_data=data.merge(finace_data_use,on="gvkey")
ana_data
# Out:
#               company_name                                     position  \
# 0        American Airlines                           Software Developer
# 1        American Airlines              Customer Service Representative
# 2        American Airlines                           Reservations Agent
# 3        American Airlines              Customer Service Representative
# 4        American Airlines              Customer Service Representative
# ...                    ...                                          ...
# 2328195     LyondellBasell              Customer Service Representative
# 2328196     LyondellBasell        Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell  Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell        Quality Control Laboratory Technician
# 2328199     LyondellBasell                               Lab Technician
#
#                  location  rate  \
# 0          Fort Worth, TX   4.0
# 1        Philadelphia, PA   3.0
# ...

# %% [markdown]
# Price To Book Value Per Share (Daily Time Series Ratio)

# %%
#
culture_data=ana_data[ana_data["culture"]>0.5]
culture_data
# Out:
#               company_name                                          position  \
# 619      American Airlines  Executive Platnium Customer Service Representive
# 899      American Airlines                    International Resolution Agent
# 1339     American Airlines              Executive Platinum Client Specialist
# 2226     American Airlines                                            SKYCAP
# 2273     American Airlines         Customer Care Manager-Global Reservations
# ...                    ...                                               ...
# 2328195     LyondellBasell                   Customer Service Representative
# 2328196     LyondellBasell             Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell       Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell             Quality Control Laboratory Technician
# 2328199     LyondellBasell                                    Lab Technician
#
#                   location  rate  \
# ...

# %%
culture_data["Price To Book Value Per Share (Daily Time Series Ratio)"].dropna()
# Out:
# 619       -1.563627
# 899       -1.563627
# 1339      -1.563627
# 2226      -1.563627
# 2273      -1.563627
#              ...
# 2325055    4.742451
# 2325056    4.742451
# 2325057    4.742451
# 2325058    4.742451
# 2325059    4.742451
# Name: Price To Book Value Per Share (Daily Time Series Ratio), Length: 510584, dtype: float64

# %%
#
compensation_data=ana_data[ana_data["compensation"]>0.5]
compensation_data
# Out:
#               company_name                                          position  \
# 453      American Airlines                                  Flight Attendant
# 619      American Airlines  Executive Platnium Customer Service Representive
# 899      American Airlines                    International Resolution Agent
# 1339     American Airlines              Executive Platinum Client Specialist
# 1497     American Airlines                                    Reservationist
# ...                    ...                                               ...
# 2328195     LyondellBasell                   Customer Service Representative
# 2328196     LyondellBasell             Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell       Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell             Quality Control Laboratory Technician
# 2328199     LyondellBasell                                    Lab Technician
#
#                location  rate  \
# ...

# %%
work_life_data=ana_data[ana_data["work life balance"]>0.5]
work_life_data
# Out:
#               company_name                                          position  \
# 619      American Airlines  Executive Platnium Customer Service Representive
# 899      American Airlines                    International Resolution Agent
# 1339     American Airlines              Executive Platinum Client Specialist
# 1497     American Airlines                                    Reservationist
# 2226     American Airlines                                            SKYCAP
# ...                    ...                                               ...
# 2328195     LyondellBasell                   Customer Service Representative
# 2328196     LyondellBasell             Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell       Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell             Quality Control Laboratory Technician
# 2328199     LyondellBasell                                    Lab Technician
#
#                   location  rate  \
# ...

# %%
career_opportunity_data=ana_data[ana_data["career opportunity"]>0.5]
career_opportunity_data
# Out:
#               company_name                                          position  \
# 619      American Airlines  Executive Platnium Customer Service Representive
# 899      American Airlines                    International Resolution Agent
# 1339     American Airlines              Executive Platinum Client Specialist
# 1497     American Airlines                                    Reservationist
# 1536     American Airlines                     Java Spring Angular Developer
# ...                    ...                                               ...
# 2328195     LyondellBasell                   Customer Service Representative
# 2328196     LyondellBasell             Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell       Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell             Quality Control Laboratory Technician
# 2328199     LyondellBasell                                    Lab Technician
#
#                location  rate  \
# ...

# %% [markdown]
# T-tese:

# %%
culture_data[(culture_data["sen_flag"]==1)].loc[:,"Price To Book Value Per Share (Daily Time Series Ratio)"].dropna()
# Out:
# 899       -1.563627
# 1339      -1.563627
# 2226      -1.563627
# 2273      -1.563627
# 2339      -1.563627
#              ...
# 2325052    4.742451
# 2325054    4.742451
# 2325056    4.742451
# 2325058    4.742451
# 2325059    4.742451
# Name: Price To Book Value Per Share (Daily Time Series Ratio), Length: 302068, dtype: float64

# %%
career_opportunity_data
# Out:
#               company_name                                          position  \
# 619      American Airlines  Executive Platnium Customer Service Representive
# 899      American Airlines                    International Resolution Agent
# 1339     American Airlines              Executive Platinum Client Specialist
# 1497     American Airlines                                    Reservationist
# 1536     American Airlines                     Java Spring Angular Developer
# ...                    ...                                               ...
# 2328195     LyondellBasell                   Customer Service Representative
# 2328196     LyondellBasell             Lead, Customer Solutions Supply Chain
# 2328197     LyondellBasell       Analytical Chemist/Assistant Lab Supervisor
# 2328198     LyondellBasell             Quality Control Laboratory Technician
# 2328199     LyondellBasell                                    Lab Technician
#
#                location  rate  \
# ...

# %%
stats.ttest_ind(ana_data[(ana_data["sen_flag"]==1)].loc[:,"Price To Book Value Per Share (Daily Time Series Ratio)"].dropna(), ana_data[(ana_data["sen_flag"]==-1)].loc[:,"Price To Book Value Per Share (Daily Time Series Ratio)"].dropna())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-49433033961e> in <module>()
# ----> 1 stats.ttest_ind(ana_data[(ana_data["sen_flag"]==1)].loc[:,"Price To Book Value Per Share (Daily Time Series Ratio)"].dropna(), ana_data[(ana_data["sen_flag"]==-1)].loc[:,"Price To Book Value Per Share (Daily Time Series Ratio)"].dropna())
#
# NameError: name 'stats' is not defined

# %%
label="Return on Invested Capital - %"

# %%
stats.ttest_ind(career_opportunity_data[(career_opportunity_data["sen_flag"]==1)].loc[:,label].dropna(), career_opportunity_data[(career_opportunity_data["sen_flag"]==-1)].loc[:,label].dropna())
# Out:
# Ttest_indResult(statistic=-11.445723202540224, pvalue=2.4964354816299988e-30)

# %%
ana_data.loc[:,"Return on Average Total Assets - %, TTM"].dropna()

# %% [markdown]
# calculate

# %%
culture_result=culture_data[["sen_flag","Price To Book Value Per Share (Daily Time Series Ratio)","Return on Invested Capital - %","Return on Average Total Assets - %, TTM"]].groupby("sen_flag").mean()
culture_result

# %%
compensation_result=compensation_data[["sen_flag","Price To Book Value Per Share (Daily Time Series Ratio)","Return on Invested Capital - %","Return on Average Total Assets - %, TTM"]].groupby("sen_flag").mean()
compensation_result

# %%
work_life_result=work_life_data[["sen_flag","Price To Book Value Per Share (Daily Time Series Ratio)","Return on Invested Capital - %","Return on Average Total Assets - %, TTM"]].groupby("sen_flag").mean()
work_life_result

# %%
opp_result=career_opportunity_data[["sen_flag","Price To Book Value Per Share (Daily Time Series Ratio)","Return on Invested Capital - %","Return on Average Total Assets - %, TTM"]].groupby("sen_flag").mean()
opp_result

# %% [markdown]
# Price To Book Value

# %%
culture_result.columns=["culture","culture_","culture__"]
compensation_result.columns=["compensation","compensation_","compensation__"]
work_life_result.columns=["work life","work life_","work life__"]
opp_result.columns=["opp_result","opp_result_","opp_result__"]

# %%
book_value=pd.DataFrame([culture_result["culture"],compensation_result["compensation"],work_life_result["work life"],opp_result["opp_result"]]).T
book_value

# %%
book_value=book_value.T
book_value["difference"]=book_value[-1]-book_value[1]
book_value

# %%
from scipy import stats

# %%
stats.ttest_ind(book_value[-1], book_value[1])

# %%
stats.ttest_ind(book_value[-1], book_value[0])

# %%
stats.ttest_ind(book_value[0], book_value[1])

# %% [markdown]
# Return on Invest Captial

# %%
return_cap_value=pd.DataFrame([culture_result["culture_"],compensation_result["compensation_"],work_life_result["work life_"],opp_result["opp_result_"]]).T
return_cap_value

# %%
return_cap_value=return_cap_value.T
return_cap_value["difference"]=return_cap_value[-1]-return_cap_value[1]
return_cap_value

# %%
stats.ttest_ind(return_cap_value[-1], return_cap_value[1])

# %%
stats.ttest_ind(return_cap_value[-1], return_cap_value[0])

# %%
stats.ttest_ind(return_cap_value[0], return_cap_value[1])

# %% [markdown]
# return on assets

# %%
return_asset_value=pd.DataFrame([culture_result["culture__"],compensation_result["compensation__"],work_life_result["work life__"],opp_result["opp_result__"]]).T
return_asset_value

# %%
return_asset_value=return_asset_value.T
return_asset_value["difference"]=return_asset_value[-1]-return_asset_value[1]
return_asset_value

# %%
stats.ttest_ind(return_asset_value[1], return_asset_value[-1])

# %%
stats.ttest_ind(return_asset_value[0], return_asset_value[-1])

# %%
stats.ttest_ind(return_asset_value[0], return_asset_value[1])
